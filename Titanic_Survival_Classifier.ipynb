# %% [markdown]
# <a href="https://colab.research.google.com/github/LikhithaReddyp2/TitanicClassifier/blob/main/Titanic_Survival_Classifier.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings("ignore", category=UserWarning)

# %%
data = pd.read_csv("/content/Titanic-Dataset.csv")
data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 886      0            211536  13.0000   NaN        S
# 887      0            112053  30.0000   B42        S
# 888      2        W./C. 6607  23.4500   NaN        S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500   NaN        Q
#
# [891 rows x 12 columns]

# %%
data.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
data.tail()
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
data.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
data.isna().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
import matplotlib.pyplot as plt
import seaborn as sns

corr_matrix = data.corr()
plt.figure(figsize=(8, 6))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', fmt=".2f", linewidths=.5)
plt.title('Correlation Matrix Heatmap')
plt.show()
# Out:
# <ipython-input-10-3377cb161116>:7: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr_matrix = data.corr()

# %%
sns.countplot(x='Survived',data=data)
data['Survived'].value_counts()
plt.show()

# %%
sns.countplot(x='Pclass',data=data)
data['Pclass'].value_counts()
plt.show()

# %%
sns.countplot(x='Embarked',data=data)
data['Embarked'].value_counts()
plt.show()

# %%
sns.countplot(x='Parch',data=data)
data['Parch'].value_counts()
plt.show()

# %%
sns.countplot(x='SibSp',data=data)
data['SibSp'].value_counts()
plt.show()

# %%
sns.countplot(x='Sex',data=data)
data['Sex'].value_counts()
plt.show()

# %%
for i in data.columns:
    try:
        sns.boxplot(x=i,data=data)
        plt.show()
    except:
        pass

# %%
data.drop(['PassengerId','Ticket','Cabin','Name'],axis=1,inplace=True)
data.head()
# Out:
#    Survived  Pclass     Sex   Age  SibSp  Parch     Fare Embarked
# 0         0       3    male  22.0      1      0   7.2500        S
# 1         1       1  female  38.0      1      0  71.2833        C
# 2         1       3  female  26.0      0      0   7.9250        S
# 3         1       1  female  35.0      1      0  53.1000        S
# 4         0       3    male  35.0      0      0   8.0500        S

# %%
data.Age=data.Age.fillna(data.Age.mean())
data.isna().sum()
# Out:
# Survived    0
# Pclass      0
# Sex         0
# Age         0
# SibSp       0
# Parch       0
# Fare        0
# Embarked    2
# dtype: int64

# %%
data.Embarked=data.Embarked.fillna('S')
data.isna().sum()
# Out:
# Survived    0
# Pclass      0
# Sex         0
# Age         0
# SibSp       0
# Parch       0
# Fare        0
# Embarked    0
# dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder
le1=LabelEncoder()
data['Sex']=le1.fit_transform(data['Sex'])
data['Embarked']=le1.fit_transform(data['Embarked'])
data.head()
# Out:
#    Survived  Pclass  Sex   Age  SibSp  Parch     Fare  Embarked
# 0         0       3    1  22.0      1      0   7.2500         2
# 1         1       1    0  38.0      1      0  71.2833         0
# 2         1       3    0  26.0      0      0   7.9250         2
# 3         1       1    0  35.0      1      0  53.1000         2
# 4         0       3    1  35.0      0      0   8.0500         2

# %%
from sklearn.model_selection import train_test_split
x=data.drop(["Survived"],axis=1)
y=data["Survived"]
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.25,random_state=101)

# %%
from sklearn.model_selection import cross_validate
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.neural_network import MLPClassifier
from xgboost import XGBClassifier
import pandas as pd

classifiers = {
    "KNN": KNeighborsClassifier(),
    "LR": LogisticRegression(max_iter=1000),
    "DT": DecisionTreeClassifier(),
    "RF": RandomForestClassifier(),
    "SVM": SVC(),
    "MLP": MLPClassifier(max_iter=1000),
    "XGB": XGBClassifier(),
}

results = pd.DataFrame(columns=["Classifier", "Avg_Accuracy", "Avg_F1_Score", "Avg_Overall"])

for name, clf in classifiers.items():
    model = clf
    cv_results = cross_validate(
        model, x_train, y_train, cv=10,
        scoring=(['accuracy', 'f1'])
    )

    avg_accuracy = cv_results['test_accuracy'].mean()
    avg_f1_score = cv_results['test_f1'].mean()
    avg_overall = (avg_accuracy + avg_f1_score) / 2

    results = results.append({
        "Classifier": name,
        "Avg_Accuracy": avg_accuracy,
        "Avg_F1_Score": avg_f1_score,
        "Avg_Overall": avg_overall
    }, ignore_index=True)

results = results.sort_values("Avg_Overall", ascending=False)
print(results)
# Out:
# <ipython-input-24-652692757fd5>:37: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append({
# <ipython-input-24-652692757fd5>:37: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append({
# <ipython-input-24-652692757fd5>:37: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append({
# <ipython-input-24-652692757fd5>:37: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append({
# <ipython-input-24-652692757fd5>:37: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append({
# <ipython-input-24-652692757fd5>:37: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append({
#   Classifier  Avg_Accuracy  Avg_F1_Score  Avg_Overall
# 6        XGB      0.818951      0.745918     0.782434
# 3         RF      0.812958      0.737956     0.775457
# 1         LR      0.805382      0.723117     0.764250
# 2         DT      0.780077      0.692444     0.736261
# 0        KNN      0.711171      0.578849     0.645010
# 5        MLP      0.712664      0.548474     0.630569
# 4        SVM      0.673587      0.357717     0.515652
# <ipython-input-24-652692757fd5>:37: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append({

# %%
plt.figure(figsize=(12, 6))
sns.barplot(data=results, x="Avg_Overall", y="Classifier")
plt.title("Analysis of Various Classifiers Performance")

plt.show()

# %%
from sklearn.metrics import accuracy_score,f1_score,confusion_matrix

classifier = XGBClassifier()
classifier.fit(x_train,y_train)
y_p = classifier.predict(x_train)
print(f"Train Accuracy: {accuracy_score(y_train, y_p)}")
print(f"Train F1-Score: {f1_score(y_train, y_p)}")
sns.heatmap(confusion_matrix(y_train, y_p), fmt='.3g', annot=True, cmap='Blues')
plt.show()
# Out:
# Train Accuracy: 0.9700598802395209
# Train F1-Score: 0.9588477366255144

# %%
from sklearn.metrics import accuracy_score,f1_score,confusion_matrix

classifier = XGBClassifier()
classifier.fit(x_train,y_train)
y_pred = classifier.predict(x_test)
print(f"Test Accuracy: {accuracy_score(y_test, y_pred)}")
print(f"Test F1-Score: {f1_score(y_test, y_pred)}")
sns.heatmap(confusion_matrix(y_test, y_pred), fmt='.3g', annot=True, cmap='Blues')
plt.show()
# Out:
# Test Accuracy: 0.7982062780269058
# Test F1-Score: 0.7398843930635838

# %%
from sklearn.metrics import classification_report

print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.78      0.90      0.84       127
#            1       0.83      0.67      0.74        96
#
#     accuracy                           0.80       223
#    macro avg       0.81      0.78      0.79       223
# weighted avg       0.80      0.80      0.79       223

# %%
print("Prediciting...")
Pclass = int(input("Enter Passenger Class: "))
sex = input("Enter Sex of the Passenger: ")
Sex = 0 if "F" or "f" in sex else 1
Age = int(input("Enter age of the passenger: "))
SibSp = int(input("Enter SibSp of the passenger: "))
Parch = int(input("Enter Parche of the passenger: "))
Fare = int(input("Enter Fare paid by the passenger: "))
embarked = input("Enter Embarked value of the passenger(S/C/Q): ")
Embarked=0
if embarked=="S" or embarked=="s":
  Embarked = 2
elif embarked=="C" or embarked=="c":
  Embarked= 0
else:
  Embarkedd=1

input_data = pd.DataFrame([[Pclass, Sex, Age, SibSp, Parch, Fare, Embarked]],columns=['Pclass', 'Sex', 'Age', 'SibSp', 'Parch', 'Fare', 'Embarked'])
prediction = classifier.predict(input_data)

if prediction ==1:
  print("\n\nassenger Survived.")
else:
  print("\n\nPassenger Not Survived.")
# Out:
# Prediciting...
# Enter Passenger Class: 1
# Enter Sex of the Passenger: male
# Enter age of the passenger: 24
# Enter SibSp of the passenger: 1
# Enter Parche of the passenger: 1
# Enter Fare paid by the passenger: 150
# Enter Embarked value of the passenger: 1
# Passenger Survived.
